# %% [markdown]
# ## Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 800)
def f(x):
    return np.cos(x) + 2

y = f(x)

# Plotting the function
plt.plot(x, y, color='green', linestyle='--')
plt.title('Graph of f(x) = cos(x) + 2')
plt.xlabel('x')
plt.ylabel('f(x)')

plt.show()

# %% [markdown]
# ## Task 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

def func(x):
    return np.sin(x)

a = -np.pi
b = np.pi
k = 11


actualValue, something = quad(func,a,b)
# print("adfdfasf",something)
x_actual = np.linspace(a, b, 400)
y_actual = func(x_actual)

# For 10 intervals
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.grid()
plt.plot(x_actual, y_actual, label="cos(x)", color='black')
plt.title("Riemann Sum using 10 intervals for f(x) = cos(x)")
plt.xlabel('x')
plt.ylabel('y')

n = k - 1
delta = (b - a) / n
x = np.linspace(a, b, k)
x_mid = (x[1:] + x[:-1])/2
print("X mids ",x_mid)
y_mid = func(x_mid)


riemannMid10 = delta * sum(y_mid);
errRiemannMid10 = abs(riemannMid10 - actualValue)

plt.bar(x_mid, y_mid, width=delta, align="center", alpha=0.4, color="purple", edgecolor="black")

# For 100 intervals

plt.subplot(1,2,2)
plt.grid()
plt.plot(x_actual, y_actual, label="cos(x)", color='black')
plt.title("Riemann Sum using 100 intervals for f(x) = cos(x)")
plt.xlabel('x') 
plt.ylabel('y') 
k= 100 
n = k - 1
delta = (b - a) / n
x = np.linspace(a, b, k)
x_mid = (x[1:] + x[:-1])/2
y_mid = func(x_mid)

riemannMid100 = delta * sum(y_mid);
errRiemannMid100 = abs(riemannMid100 - actualValue)

plt.bar(x_mid, y_mid, width=delta, align="center", alpha=0.4, color="green", edgecolor="black")
plt.tight_layout()

print(f"Actual Value: {actualValue}")

print(f"Riemann Midpoint with 10 intervals: {riemannMid10}")
print(f"Error Riemann Midpoint with 10 intervals: {errRiemannMid10}")

print(f"Riemann Midpoint with 100 intervals: {riemannMid100}")
print(f"Error Riemann Midpoint with 100 intervals: {errRiemannMid100}")
# Out:
# X mids  [-2.82743339 -2.19911486 -1.57079633 -0.9424778  -0.31415927  0.31415927
#   0.9424778   1.57079633  2.19911486  2.82743339]
# Actual Value: 2.615901373506474e-16
# Riemann Midpoint with 10 intervals: 1.3951473992034527e-16
# Error Riemann Midpoint with 10 intervals: 1.220753974303021e-16
# Riemann Midpoint with 100 intervals: -2.607093624774129e-16
# Error Riemann Midpoint with 100 intervals: 5.222994998280603e-16
